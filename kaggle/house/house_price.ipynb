# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('./data/train.csv')

# %%
df.head()
# Out:
#    id             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0   0  20141013T000000  221900.0         3       1.00         1180      5650
# 1   1  20150225T000000  180000.0         2       1.00          770     10000
# 2   2  20150218T000000  510000.0         3       2.00         1680      8080
# 3   3  20140627T000000  257500.0         3       2.25         1715      6819
# 4   4  20150115T000000  291850.0         3       1.50         1060      9711
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     1.0           0     0  ...      6         770              0      1933
# 2     1.0           0     0  ...      8        1680              0      1987
# 3     2.0           0     0  ...      7        1715              0      1995
# 4     1.0           0     0  ...      7        1060              0      1963
#
# ...

# %%
print(df.shape)
# Out:
# (15035, 21)

# %% [markdown]
# ## 데이터 탐색

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# - ID : 집을 구분하는 번호
# - date : 집을 구매한 날짜
# - price : 집의 가격(Target variable)
# - bedrooms : 침실의 수
# - bathrooms : 침실 개수 당 화장실의 수(화장실의 수 / 침실의 수 )
# - sqft_living : 주거 공간의 평방 피트(면적)
# - sqft_lot : 부지의 평방 피트(면적)
# - floors : 집의 층 수
# - waterfront : 집의 전방에 강이 흐르는지 유무 (a.k.a. 리버뷰)
# - view : 집이 얼마나 좋아 보이는지의 정도
# - condition : 집의 전반적인 상태
# - grade : King County grading 시스템 기준으로 매긴 집의 등급
# - sqft_above : 지하실을 제외한 평방 피트(면적)
# - sqft_basement : 지하실의 평방 피트(면적)
# - yr_built : 지어진 년도
# - yr_renovated : 집을 재건축한 년도
# - zipcode : 우편번호
# - lat : 위도
# - long : 경도
# - sqft_living15 : 2015년 기준 주거 공간의 평방 피트(면적, 집을 재건축했다면, 변화가 있을 수 있음)
# - sqft_lot15 : 2015년 기준 부지의 평방 피트(면적, 집을 재건축했다면, 변화가 있을 수 있음)

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15035 entries, 0 to 15034
# Data columns (total 21 columns):
# id               15035 non-null int64
# date             15035 non-null object
# price            15035 non-null float64
# bedrooms         15035 non-null int64
# bathrooms        15035 non-null float64
# sqft_living      15035 non-null int64
# sqft_lot         15035 non-null int64
# floors           15035 non-null float64
# waterfront       15035 non-null int64
# view             15035 non-null int64
# condition        15035 non-null int64
# grade            15035 non-null int64
# sqft_above       15035 non-null int64
# sqft_basement    15035 non-null int64
# yr_built         15035 non-null int64
# yr_renovated     15035 non-null int64
# zipcode          15035 non-null int64
# lat              15035 non-null float64
# long             15035 non-null float64
# sqft_living15    15035 non-null int64
# sqft_lot15       15035 non-null int64
# ...

# %% [markdown]
# null도 없고, 빈것도 없고, 문자열도 없고... 행복 그자체...?

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  15035.000000  1.503500e+04  15035.000000  15035.000000  15035.000000
# mean    7517.000000  5.406827e+05      3.369139      2.115065   2083.790223
# std     4340.374984  3.715247e+05      0.902721      0.767519    922.134087
# min        0.000000  7.800000e+04      0.000000      0.000000    290.000000
# 25%     3758.500000  3.220000e+05      3.000000      1.750000   1430.000000
# 50%     7517.000000  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    11275.500000  6.450000e+05      4.000000      2.500000   2560.000000
# max    15034.000000  7.700000e+06     10.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  1.503500e+04  15035.000000  15035.000000  15035.000000  15035.000000
# mean   1.529697e+04      1.498071      0.007117      0.234253      3.406651
# ...

# %%
df.hist(bins=10,figsize=(10,10),grid=False);

# %% [markdown]
# heatmap으로 상관계수를 시각화하고, 일정 값 이상인 것만 사용하여 예측해보자

# %%
corr=df.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, vmax=.8, linewidths=0.01,
            square=True,annot=True,fmt='.2f',cmap='YlGnBu',linecolor="white")
plt.title('Correlation between features');

# %% [markdown]
# 상관계수가 0.6이상이거나 근사시켜서 0.6이상인걸로 구해보자
#
# price는 sqft_living과 grade, sqft_above, aqft_living15와 연관이 있어보인다.

# %% [markdown]
# ## scikit-learn 선형회귀 모델(without 전처리)

# %%
X = df[['sqft_living','grade','sqft_above','sqft_living15']]
X.head()
# Out:
#    sqft_living  grade  sqft_above  sqft_living15
# 0         1180      7        1180           1340
# 1          770      6         770           2720
# 2         1680      8        1680           1800
# 3         1715      7        1715           2238
# 4         1060      7        1060           1650

# %%
Y = df['price']
Y.head()
# Out:
# 0    221900.0
# 1    180000.0
# 2    510000.0
# 3    257500.0
# 4    291850.0
# Name: price, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pre = lr.predict(X)
plt.scatter(pre,Y, s=10)
plt.xlabel("Predicted price")
plt.ylabel("Actual price")

plt.show()

# %% [markdown]
# 전처리를 하지 않으니 실제값과 많이 차이 나는것 같다. 엉엉

# %% [markdown]
# ### Normalization

# %%
X.head()
# Out:
#    sqft_living  grade  sqft_above  sqft_living15
# 0         1180      7        1180           1340
# 1          770      6         770           2720
# 2         1680      8        1680           1800
# 3         1715      7        1715           2238
# 4         1060      7        1060           1650

# %%
X_norm = X

for a in X.columns:
    f_max = X[a].max()
    X_norm[a] = X_norm[a].apply(lambda x: x/f_max)
X_norm.head()
# Out:
# /anaconda3/envs/kaggle/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#    sqft_living     grade  sqft_above  sqft_living15
# 0     0.087149  0.538462    0.125399       0.215781
# 1     0.056869  0.461538    0.081828       0.438003
# 2     0.124077  0.615385    0.178533       0.289855
# 3     0.126662  0.538462    0.182253       0.360386
# 4     0.078287  0.538462    0.112646       0.265700

# %%
lr_norm = LinearRegression()
lr_norm.fit(X_norm,Y)

pre_norm = lr.predict(X_norm)
plt.scatter(pre_norm,Y, s=10)
plt.xlabel("Predicted price")
plt.ylabel("Actual price")

plt.show()

# %% [markdown]
# 뭐지 뭐가 잘못 된거지?.......... 히트맵에서 색이 진한것을 쓰는게 아니라 빼야하는건가?

# %% [markdown]
# ## 날짜 처리해보기

# %%
df['date'] = df['date'].apply(lambda x : str(x[:6])).astype(int)
df.head()
# Out:
#    id    date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0   0  201410  221900.0         3       1.00         1180      5650     1.0
# 1   1  201502  180000.0         2       1.00          770     10000     1.0
# 2   2  201502  510000.0         3       2.00         1680      8080     1.0
# 3   3  201406  257500.0         3       2.25         1715      6819     2.0
# 4   4  201501  291850.0         3       1.50         1060      9711     1.0
#
#    waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0  ...      7        1180              0      1955
# 1           0     0  ...      6         770              0      1933
# 2           0     0  ...      8        1680              0      1987
# 3           0     0  ...      7        1715              0      1995
# 4           0     0  ...      7        1060              0      1963
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
del df['id']

# %%
df.head()
# Out:
#      date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  201410  221900.0         3       1.00         1180      5650     1.0
# 1  201502  180000.0         2       1.00          770     10000     1.0
# 2  201502  510000.0         3       2.00         1680      8080     1.0
# 3  201406  257500.0         3       2.25         1715      6819     2.0
# 4  201501  291850.0         3       1.50         1060      9711     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      6         770              0      1933
# 2           0     0          3      8        1680              0      1987
# 3           0     0          3      7        1715              0      1995
# 4           0     0          3      7        1060              0      1963
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
fig, ax = plt.subplots(10, 2, figsize=(20, 60))

# id 변수는 제외하고 분포를 확인합니다.
count = 0
columns = df.columns
for row in range(10):
    for col in range(2):
        sns.kdeplot(df[columns[count]], ax=ax[row][col])
        ax[row][col].set_title(columns[count], fontsize=15)
        count+=1
        if count == 19 :
            break

# %%
plt.plot(df['data'],df['price'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'data'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-eabc200c630c> in <module>
# ...
