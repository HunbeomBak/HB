# %%
import keras
import numpy as np
# Out:
# Using TensorFlow backend.

# %% [markdown]
# 모델이랑 데이터를 만든다

# %%
x = np.array([0,1,2,3,4])
y= x*2+1

# %% [markdown]
# 케라스로 인공신경망 모델을 만들기 시작했음을 파이썬 프로세스에 알린다.

# %%
model = keras.models.Sequential()

# %% [markdown]
# model.Sequential은 파이썬 클래스, model이라는 인스턴스를 만든다.
#
# 모델 인스턴스 생성 후 add()를 이용하여 인공지능 계층을 추가한다.

# %%
model.add(keras.layers.Dense(1,input_shape=(1,)))

# %% [markdown]
# 추가한 계층은 입ㄹ겨 노드 하나와 가중치 하나를 가진 선형계층
#
# 이제 어떻게 학습할지 파라미터로 지정하고 컴파일한다.
#
# 최적화 알고리즘 : 확률적 경사 하강법(SGD)
#
# 손실 함수 : 평균제곱오차(MSE)

# %%
model.compile('SGD','mse')

# %%
model.fit(x[:2],y[:2],epochs=1000,verbose=0)

# %%
print('Target:',y[2:])
print('Predictions:', model.predict(x[2:]).flatten())
# Out:
# Target: [5 7 9]
# Predictions: [4.999976  6.9999585 8.999941 ]
