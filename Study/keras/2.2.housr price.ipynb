# %% [markdown]
# # Ex 2.2 시계열 데이터를 예측하는 회귀 ANN

# %% [markdown]
# 1. 회귀 ANN 모델링

# %%
from keras import layers, models

# %%
class ANN(models.Model):
  def __init__(self, Nin, Nh, Nout):
    #Prepare network layers and activate functions
    hidden = layers.Dense(Nh)
    output = layers.Dense(Nout)
    relu = layers.Activation('relu')
    
    #Connect network elements
    x = layers.Input(shape=(Nin,))
    h = relu(hidden(x))
    y = output(h)
    
    super().__init__(x,y)
    
    self.compile(loss='mse',optimizer='sgd')

# %% [markdown]
# 2. 데이터 불러오기

# %%
from keras import datasets
from sklearn import preprocessing
import nbimporter

# %%
def Data_func():
  (X_train, y_train), (X_test, y_test) = datasets.boston_housing.load_data()
  scaler = preprocessing.MinMaxScaler()
  X_train = scaler.fit_transform(X_train)
  X_test = scaler.transform(X_test)
  return (X_train, y_train),(X_test, y_test)

# %% [markdown]
# 3. 회귀 ANN 학습결과 그래프 구현

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plot_loss(history):
  #summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('Model loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(['Train','Test'],loc=0)

# %% [markdown]
# 4. 회귀 ANN 학습 및 성능 분석

# %%
def main():
  Nin = 13
  Nh = 5
  Nout = 1
  
  model = ANN(Nin,Nh,Nout)
  (X_train,y_train),(X_test,y_test) = Data_func()
  
  history = model.fit(X_train, y_train, epochs=100, batch_size=100, validation_split=0.2, verbose=2)
  
  performance_test = model.evaluate(X_test, y_test, batch_size=100)
  print('\nTest Loss -> {:.2f}'.format(performance_test))
  
  plot_loss(history)
  plt.show()

# %% [markdown]
# 5. 실행

# %%
if __name__=='__main__':
  main()
# Out:
# Downloading data from https://s3.amazonaws.com/keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 4us/step
# Train on 323 samples, validate on 81 samples
# Epoch 1/100
#  - 1s - loss: 490.7654 - val_loss: 118.0998
# Epoch 2/100
#  - 0s - loss: 101.7355 - val_loss: 84.8857
# Epoch 3/100
#  - 0s - loss: 80.7012 - val_loss: 70.2537
# Epoch 4/100
#  - 0s - loss: 64.8579 - val_loss: 71.6705
# Epoch 5/100
#  - 0s - loss: 56.9253 - val_loss: 53.3526
# Epoch 6/100
#  - 0s - loss: 56.0277 - val_loss: 59.7435
# Epoch 7/100
#  - 0s - loss: 75.3962 - val_loss: 49.3529
# Epoch 8/100
#  - 0s - loss: 46.9912 - val_loss: 88.7519
# Epoch 9/100
#  - 0s - loss: 61.9077 - val_loss: 61.3118
# Epoch 10/100
#  - 0s - loss: 45.6545 - val_loss: 51.8330
# Epoch 11/100
#  - 0s - loss: 41.1096 - val_loss: 43.1451
# Epoch 12/100
#  - 0s - loss: 38.0744 - val_loss: 37.0719
# Epoch 13/100
#  - 0s - loss: 35.7294 - val_loss: 53.7336
# Epoch 14/100
#  - 0s - loss: 43.5031 - val_loss: 41.1703
# Epoch 15/100
#  - 0s - loss: 44.3071 - val_loss: 48.1746
# Epoch 16/100
#  - 0s - loss: 35.1284 - val_loss: 52.0698
# Epoch 17/100
#  - 0s - loss: 34.7474 - val_loss: 34.2720
# Epoch 18/100
#  - 0s - loss: 31.8964 - val_loss: 40.7051
# Epoch 19/100
#  - 0s - loss: 31.7633 - val_loss: 32.9168
# Epoch 20/100
#  - 0s - loss: 28.7987 - val_loss: 27.5502
# Epoch 21/100
#  - 0s - loss: 28.2313 - val_loss: 26.5015
# Epoch 22/100
#  - 0s - loss: 28.0788 - val_loss: 28.1837
# Epoch 23/100
#  - 0s - loss: 26.2460 - val_loss: 28.4614
# Epoch 24/100
#  - 0s - loss: 26.4531 - val_loss: 25.7572
# Epoch 25/100
#  - 0s - loss: 25.7346 - val_loss: 28.7758
# Epoch 26/100
#  - 0s - loss: 34.7892 - val_loss: 33.3182
# Epoch 27/100
#  - 0s - loss: 26.6141 - val_loss: 24.0981
# Epoch 28/100
#  - 0s - loss: 28.6556 - val_loss: 46.0746
# Epoch 29/100
#  - 0s - loss: 54.2635 - val_loss: 31.7867
# Epoch 30/100
#  - 0s - loss: 34.3139 - val_loss: 84.5085
# Epoch 31/100
#  - 0s - loss: 79.2782 - val_loss: 25.2755
# Epoch 32/100
#  - 0s - loss: 24.7477 - val_loss: 37.5093
# Epoch 33/100
#  - 0s - loss: 63.2218 - val_loss: 28.9462
# Epoch 34/100
#  - 0s - loss: 30.2988 - val_loss: 23.6245
# Epoch 35/100
#  - 0s - loss: 24.4342 - val_loss: 29.3235
# Epoch 36/100
#  - 0s - loss: 24.6918 - val_loss: 39.6048
# Epoch 37/100
#  - 0s - loss: 55.5187 - val_loss: 21.1792
# Epoch 38/100
#  - 0s - loss: 23.3269 - val_loss: 22.9839
# Epoch 39/100
#  - 0s - loss: 24.5980 - val_loss: 20.2208
# Epoch 40/100
#  - 0s - loss: 25.3979 - val_loss: 21.0369
# Epoch 41/100
#  - 0s - loss: 22.7704 - val_loss: 23.7699
# Epoch 42/100
#  - 0s - loss: 26.0718 - val_loss: 20.6683
# Epoch 43/100
#  - 0s - loss: 22.6390 - val_loss: 24.1480
# Epoch 44/100
#  - 0s - loss: 23.7732 - val_loss: 20.4678
# Epoch 45/100
#  - 0s - loss: 25.2801 - val_loss: 34.1109
# Epoch 46/100
#  - 0s - loss: 31.8427 - val_loss: 20.9073
# Epoch 47/100
#  - 0s - loss: 23.2833 - val_loss: 46.1138
# Epoch 48/100
#  - 0s - loss: 34.1768 - val_loss: 25.4199
# Epoch 49/100
#  - 0s - loss: 22.5345 - val_loss: 22.3983
# Epoch 50/100
#  - 0s - loss: 22.2700 - val_loss: 31.9003
# Epoch 51/100
#  - 0s - loss: 40.6064 - val_loss: 20.9780
# Epoch 52/100
#  - 0s - loss: 21.6680 - val_loss: 19.5597
# Epoch 53/100
#  - 0s - loss: 21.8532 - val_loss: 37.8053
# Epoch 54/100
#  - 0s - loss: 26.6179 - val_loss: 39.4729
# Epoch 55/100
#  - 0s - loss: 33.5304 - val_loss: 59.0994
# Epoch 56/100
#  - 0s - loss: 36.4000 - val_loss: 54.1811
# Epoch 57/100
#  - 0s - loss: 38.5945 - val_loss: 23.3090
# Epoch 58/100
#  - 0s - loss: 23.1236 - val_loss: 18.8070
# Epoch 59/100
#  - 0s - loss: 21.5438 - val_loss: 21.3895
# Epoch 60/100
#  - 0s - loss: 21.8833 - val_loss: 31.1166
# Epoch 61/100
#  - 0s - loss: 24.4969 - val_loss: 25.2964
# Epoch 62/100
#  - 0s - loss: 22.8096 - val_loss: 22.5109
# Epoch 63/100
#  - 0s - loss: 30.8953 - val_loss: 18.9154
# Epoch 64/100
#  - 0s - loss: 20.8710 - val_loss: 22.8186
# Epoch 65/100
#  - 0s - loss: 28.8082 - val_loss: 51.0391
# Epoch 66/100
#  - 0s - loss: 49.3332 - val_loss: 18.3140
# Epoch 67/100
#  - 0s - loss: 23.7975 - val_loss: 27.4759
# Epoch 68/100
#  - 0s - loss: 28.5576 - val_loss: 18.3924
# Epoch 69/100
#  - 0s - loss: 20.2915 - val_loss: 18.4344
# Epoch 70/100
#  - 0s - loss: 20.0632 - val_loss: 19.4291
# Epoch 71/100
#  - 0s - loss: 23.0746 - val_loss: 17.6054
# Epoch 72/100
#  - 0s - loss: 22.9563 - val_loss: 17.8111
# Epoch 73/100
#  - 0s - loss: 21.6144 - val_loss: 17.6862
# Epoch 74/100
#  - 0s - loss: 20.1938 - val_loss: 29.9661
# Epoch 75/100
#  - 0s - loss: 25.6817 - val_loss: 19.9884
# Epoch 76/100
#  - 0s - loss: 20.3641 - val_loss: 17.7854
# Epoch 77/100
#  - 0s - loss: 23.9054 - val_loss: 22.5318
# Epoch 78/100
#  - 0s - loss: 22.7409 - val_loss: 16.8334
# Epoch 79/100
#  - 0s - loss: 19.7347 - val_loss: 18.4844
# Epoch 80/100
#  - 0s - loss: 19.3444 - val_loss: 22.9451
# Epoch 81/100
#  - 0s - loss: 27.5646 - val_loss: 28.2247
# Epoch 82/100
#  - 0s - loss: 35.0796 - val_loss: 21.2609
# Epoch 83/100
#  - 0s - loss: 22.2039 - val_loss: 17.6513
# Epoch 84/100
#  - 0s - loss: 20.5554 - val_loss: 23.6470
# Epoch 85/100
#  - 0s - loss: 27.3694 - val_loss: 16.3703
# Epoch 86/100
#  - 0s - loss: 20.4155 - val_loss: 21.4072
# Epoch 87/100
#  - 0s - loss: 32.3325 - val_loss: 41.6198
# Epoch 88/100
#  - 0s - loss: 29.5272 - val_loss: 17.5927
# Epoch 89/100
#  - 0s - loss: 18.9529 - val_loss: 17.0991
# Epoch 90/100
#  - 0s - loss: 18.3084 - val_loss: 16.5171
# Epoch 91/100
#  - 0s - loss: 20.6048 - val_loss: 19.1375
# Epoch 92/100
#  - 0s - loss: 18.6349 - val_loss: 19.4798
# Epoch 93/100
#  - 0s - loss: 22.0018 - val_loss: 15.5346
# Epoch 94/100
#  - 0s - loss: 18.7370 - val_loss: 18.5980
# Epoch 95/100
#  - 0s - loss: 17.9024 - val_loss: 15.3783
# Epoch 96/100
#  - 0s - loss: 18.2034 - val_loss: 15.7364
# Epoch 97/100
#  - 0s - loss: 17.7484 - val_loss: 16.4096
# Epoch 98/100
#  - 0s - loss: 17.7299 - val_loss: 15.4824
# Epoch 99/100
#  - 0s - loss: 18.3292 - val_loss: 36.8165
# Epoch 100/100
#  - 0s - loss: 29.6944 - val_loss: 30.5234
# 102/102 [==============================] - 0s 99us/step
#
# Test Loss -> 36.01
